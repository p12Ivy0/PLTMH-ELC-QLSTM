# %% [markdown]
# <a href="https://colab.research.google.com/github/p12Ivy0/PLTMH-ELC-QLSTM/blob/main/notebooks/00_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/p12Ivy0/PLTMH-ELC-QLSTM/blob/main/notebooks/00_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

REPO_URL = "https://github.com/p12Ivy0/PLTMH-ELC-QLSTM"
PROJECT_DIR = "/content/PLTMH-ELC-QLSTM"

if os.path.exists(PROJECT_DIR):
    # %cd /content/PLTMH-ELC-QLSTM
    # !git pull
else:
    # %cd /content
    # !git clone {REPO_URL}
    # %cd /content/PLTMH-ELC-QLSTM

print("\nProject directory:")
# !pwd
# Out:
# /content/PLTMH-ELC-QLSTM
# Already up to date.
#
# Project directory:
# /content/PLTMH-ELC-QLSTM

# %%
print("=== Git status ===")
# !git status

print("\n=== Remote repository ===")
# !git remote -v

print("\n=== Branch aktif ===")
# !git branch --show-current
# Out:
# === Git status ===
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
#
# === Remote repository ===
# origin	https://github.com/p12Ivy0/PLTMH-ELC-QLSTM (fetch)
# origin	https://github.com/p12Ivy0/PLTMH-ELC-QLSTM (push)
#
# === Branch aktif ===
# main

# %%
import os

print("Isi root project:\n")

for item in sorted(os.listdir(PROJECT_DIR)):
    print(item)
# Out:
# Isi root project:
#
# .git
# .gitignore
# README.md
# config
# docs
# notebooks
# pytest.ini
# requirements.txt
# src
# tests

# %%
requirements_file = os.path.join(PROJECT_DIR, "requirements.txt")

if os.path.exists(requirements_file):
    print("Installing dependencies...")
    # !pip install -q -r requirements.txt
else:
    print("requirements.txt belum tersedia.")
# Out:
# Installing dependencies...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 43.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 937.5/937.5 kB 24.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.5/25.5 MB 52.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 78.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.2/167.2 kB 17.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 114.8 MB/s eta 0:00:00

# %%
import sys

if PROJECT_DIR not in sys.path:
    sys.path.insert(0, PROJECT_DIR)

print("Python project path:")
print(sys.path[0])
# Out:
# Python project path:
# /content/PLTMH-ELC-QLSTM

# %%
import sys
import numpy as np
import scipy
import pandas as pd
import matplotlib
import sklearn

print("Python       :", sys.version.split()[0])
print("NumPy        :", np.__version__)
print("SciPy        :", scipy.__version__)
print("Pandas       :", pd.__version__)
print("Matplotlib   :", matplotlib.__version__)
print("Scikit-learn :", sklearn.__version__)
# Out:
# Python       : 3.13.15
# NumPy        : 2.1.3
# SciPy        : 1.16.3
# Pandas       : 2.2.3
# Matplotlib   : 3.10.0
# Scikit-learn : 1.6.1

# %%
import torch

print("PyTorch version :", torch.__version__)
print("CUDA available  :", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU             :", torch.cuda.get_device_name(0))
else:
    print("Device          : CPU")
# Out:
# PyTorch version : 2.11.0+cpu
# CUDA available  : False
# Device          : CPU

# %%
try:
    import pennylane as qml
    print("PennyLane version :", qml.__version__)
    print("PennyLane          : OK")
except ImportError:
    print("PennyLane belum terinstal.")
# Out:
# PennyLane version : 0.45.1
# PennyLane          : OK

# %%
import random
import numpy as np
import torch

SEED = 42

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

print(f"Random seed ditetapkan: {SEED}")
# Out:
# Random seed ditetapkan: 42

# %%
print("=" * 60)
print("PLTMH–ELC–QLSTM PROJECT SETUP")
print("=" * 60)

print(f"Project directory : {PROJECT_DIR}")
print(f"Python            : {sys.version.split()[0]}")
print(f"PyTorch           : {torch.__version__}")
print(f"CUDA              : {torch.cuda.is_available()}")

print("=" * 60)
print("Environment siap digunakan.")
print("=" * 60)
# Out:
# ...
# PLTMH–ELC–QLSTM PROJECT SETUP
# ...
# Project directory : /content/PLTMH-ELC-QLSTM
# Python            : 3.13.15
# PyTorch           : 2.11.0+cpu
# CUDA              : False
# ...
# Environment siap digunakan.
# ...
