# %% [markdown]
# <a href="https://colab.research.google.com/github/p12Ivy0/PLTMH-ELC-QLSTM/blob/main/notebooks/01_plant_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pathlib import Path
import os
import sys

REPO_URL = "https://github.com/p12Ivy0/PLTMH-ELC-QLSTM"
PROJECT_DIR = Path("/content/PLTMH-ELC-QLSTM")

# Clone repository jika belum tersedia di runtime ini
if not PROJECT_DIR.exists():
    # %cd /content
    # !git clone {REPO_URL}

# Masuk ke root project
# %cd /content/PLTMH-ELC-QLSTM

# Tambahkan root project ke Python path
if str(PROJECT_DIR) not in sys.path:
    sys.path.insert(0, str(PROJECT_DIR))

print("\nProject directory:")
# !pwd
# Out:
# /content
# Cloning into 'PLTMH-ELC-QLSTM'...
# remote: Enumerating objects: 173, done.
# remote: Counting objects: 100% (173/173), done.
# remote: Compressing objects: 100% (155/155), done.
# remote: Total 173 (delta 71), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (173/173), 48.16 KiB | 948.00 KiB/s, done.
# Resolving deltas: 100% (71/71), done.
# /content/PLTMH-ELC-QLSTM
#
# Project directory:
# /content/PLTMH-ELC-QLSTM

# %%
print("=== Working Directory ===")
# !pwd

print("\n=== Git Status ===")
# !git status

print("\n=== Git Remote ===")
# !git remote -v
# Out:
# === Working Directory ===
# /content/PLTMH-ELC-QLSTM
#
# === Git Status ===
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
#
# === Git Remote ===
# origin	https://github.com/p12Ivy0/PLTMH-ELC-QLSTM (fetch)
# origin	https://github.com/p12Ivy0/PLTMH-ELC-QLSTM (push)
